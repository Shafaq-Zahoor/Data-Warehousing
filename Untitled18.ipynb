# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import sqlite3

df_fact = pd.read_csv('/content/dataset.csv')

# %%
conn = sqlite3.connect("RFM")
cur = conn.cursor()

# %%
df_fact.to_sql("dataset", conn)
# Out:
# 38765

# %%
df_fact = pd.read_sql('SELECT * FROM dataset', conn)
df_fact
# Out:
#        index  Member_number        Date        itemDescription
# 0          0           1808  21-07-2015         tropical fruit
# 1          1           2552  05-01-2015             whole milk
# 2          2           2300  19-09-2015              pip fruit
# 3          3           1187  12-12-2015       other vegetables
# 4          4           3037  01-02-2015             whole milk
# ...      ...            ...         ...                    ...
# 38760  38760           4471  08-10-2014          sliced cheese
# 38761  38761           2022  23-02-2014                  candy
# 38762  38762           1097  16-04-2014               cake bar
# 38763  38763           1510  03-12-2014  fruit/vegetable juice
# 38764  38764           1521  26-12-2014               cat food
#
# [38765 rows x 4 columns]

# %%
clean_data = pd.read_sql('''SELECT DISTINCT Member_number, Date, itemDescription, 
               MAX(Date) AS last_order_date,
               COUNT(*) AS count_order,
               COUNT(itemDescription) AS totalitems
               FROM dataset
               WHERE Member_number IS NOT NULL
               AND Date != 0
               GROUP BY Member_number''',conn)

clean_data.to_sql("clean_data", conn)
# Out:
# 3898

# %%
df_fact = pd.read_sql('SELECT * FROM clean_data ORDER BY last_order_date DESC',conn)

df_fact
# Out:
#       index  Member_number        Date    itemDescription last_order_date  \
# 0       491           1502  31-10-2015  frozen vegetables      31-10-2015
# 1       766           1787  31-10-2015       frozen meals      31-10-2015
# 2       958           1981  31-10-2015            chicken      31-10-2015
# 3      1063           2089  31-10-2015        canned beer      31-10-2015
# 4      1394           2439  31-10-2015      bottled water      31-10-2015
# ...     ...            ...         ...                ...             ...
# 3893    229           1238  01-03-2015        frankfurter      01-03-2015
# 3894    426           1436  01-03-2015          beverages      01-03-2015
# 3895   1260           2297  01-03-2015        brown bread      01-03-2015
# 3896   2135           3197  01-03-2014            sausage      01-03-2014
# 3897   1774           2828  01-02-2014               meat      01-02-2014
#
#       count_order  totalitems
# 0               7           7
# ...

# %%
df_fact1 = pd.read_sql(''' SELECT Member_number, rfm_recency, rfm_frequency, rfm_monetary, 
rfm_recency*100 +rfm_frequency*10 + rfm_monetary AS rfm_combined
FROM
( SELECT Member_number,
NTILE(4) OVER (ORDER BY Date) AS rfm_recency,
NTILE(4) OVER (ORDER BY count_order) AS rfm_frequency,
NTILE(4) OVER (ORDER BY itemDescription) AS rfm_monetary
FROM
clean_data)'''
, conn)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


def rfma(df_fact1):
  if ((df_fact1['rfm_recency'] >= 4) and (df_fact1['rfm_frequency'] >= 4)and (df_fact1['rfm_monetary'] >= 4)):
    return 'Best Customers'
  if ((df_fact1['rfm_recency'] >= 3) and (df_fact1['rfm_frequency'] >= 3)and (df_fact1['rfm_monetary'] >= 3)):
    return 'Loyal'
  if ((df_fact1['rfm_recency'] >= 3) and (df_fact1['rfm_frequency'] >= 1)and (df_fact1['rfm_monetary'] >= 2)):
    return 'Potential Loyalist'
  if ((df_fact1['rfm_recency'] >= 3) and (df_fact1['rfm_frequency'] >= 1)and (df_fact1['rfm_monetary'] >= 1)):
    return 'Promising'
  if ((df_fact1['rfm_recency'] >= 2) and (df_fact1['rfm_frequency'] >= 2)and (df_fact1['rfm_monetary'] >= 2)):
    return 'Customers Needing Attention'
  if ((df_fact1['rfm_recency'] >= 1) and (df_fact1['rfm_frequency'] >= 2)and (df_fact1['rfm_monetary'] >= 2)):
    return 'At Risk'
  if ((df_fact1['rfm_recency'] >= 1) and (df_fact1['rfm_frequency'] >= 1)and (df_fact1['rfm_monetary'] >= 2)):
    return 'Hibernating'
  else:
    return 'Lost'

df_fact1['rfma'] = df_fact1.apply(rfma, axis =1)

# %%
df_fact1
# Out:
#       Member_number  rfm_recency  rfm_frequency  rfm_monetary  rfm_combined  \
# 0              2828            1              1             2           112
# 1              3197            1              1             3           113
# 2              1436            1              1             1           111
# 3              2297            1              1             1           111
# 4              1238            1              1             2           112
# ...             ...          ...            ...           ...           ...
# 3893           4322            4              3             1           431
# 3894           1787            4              3             2           432
# 3895           2089            4              4             1           441
# 3896           4773            4              4             3           443
# 3897           3122            4              4             1           441
#
#                     rfma
# 0            Hibernating
# ...

# %%
rfma
# Out:
# <function __main__.rfma(df_fact)>

# %%
# Calculate total customers in each segment
rfm_agg = df_fact1.groupby('rfma').agg({'Member_number':'count'})
print(rfm_agg)
# Out:
#                              Member_number
# rfma
# At Risk                                406
# Best Customers                          82
# Customers Needing Attention            570
# Hibernating                            490
# Lost                                   484
# Loyal                                  532
# Potential Loyalist                     843
# Promising                              491

# %%
# !pip install squarify
import squarify as sq
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(13, 7)
sq.plot(sizes=rfm_agg['Member_number'],
              label=['At Risk',
                     'Best Customers',
                     'Customers Needing Attention',
                     'Hibernating',
                     'Lost',
                     'Loyal',
                     'Potential Loyalist',
                     'Promising'], alpha=0.7)
plt.title("RFM Segments",fontsize=20)
plt.axis('off')
plt.show()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
df_fact1.corr()
# Out:
# <ipython-input-13-8f70529d8551>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_fact1.corr()
#                Member_number  rfm_recency  rfm_frequency  rfm_monetary  \
# Member_number       1.000000     0.004791       0.006360     -0.003845
# rfm_recency         0.004791     1.000000       0.348178     -0.005439
# rfm_frequency       0.006360     0.348178       1.000000      0.076449
# rfm_monetary       -0.003845    -0.005439       0.076449      1.000000
# rfm_combined        0.005185     0.995803       0.432040      0.011746
#
#                rfm_combined
# Member_number      0.005185
# rfm_recency        0.995803
# rfm_frequency      0.432040
# rfm_monetary       0.011746
# rfm_combined       1.000000

# %%
df_fact.dtypes
df_fact['last_order_date'] = pd.to_datetime(df_fact['last_order_date'])
df_fact.dtypes
# Create date variable that records recency
import numpy as np
import datetime
df_fact["last_order_date"] = df_fact["last_order_date"].dt.date
# Create snapshot date
snapshot_date = df_fact['last_order_date'].max() + datetime.timedelta(days=1)
print(snapshot_date)
# Out:
# 2015-12-31
# <ipython-input-14-295ede66f406>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_fact['last_order_date'] = pd.to_datetime(df_fact['last_order_date'])

# %%
customers = df_fact.groupby(['Member_number']).agg({'last_order_date': lambda x: (snapshot_date - x.max()).days,'count_order':'sum' ,'totalitems': 'sum'})

# %%
customers.rename(columns = {'last_order_date': 'Recency','count_order': 'Frequency','totalitems': 'MonetaryValue'}, inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
sns.histplot(data=customers, x='Recency', kde=True)
ax.set_title('Histogram and Recency')
# Out:
# Text(0.5, 1.0, 'Histogram and Recency')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
sns.histplot(data=customers, x='Frequency', kde=True)
ax.set_title('Histogram and Frequency')
# Out:
# Text(0.5, 1.0, 'Histogram and Frequency')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
sns.histplot(data=customers, x='MonetaryValue', kde=True)
ax.set_title('Histogram and MonetaryValue')
# Out:
# Text(0.5, 1.0, 'Histogram and MonetaryValue')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot RFM distributions
plt.figure(figsize=(12,10))
# Plot distribution of R
plt.subplot(3, 1, 1); 
sns.distplot(customers['Recency'])
# Plot distribution of F
plt.subplot(3, 1, 2); 
sns.distplot(customers['Frequency'])
# Plot distribution of M
plt.subplot(3, 1, 3); 
sns.distplot(customers['MonetaryValue'])
# Show the plot
plt.show()
# Out:
# <ipython-input-25-55e4f63783c9>:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(customers['Recency'])
# <ipython-input-25-55e4f63783c9>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(customers['Frequency'])
# <ipython-input-25-55e4f63783c9>:14: UserWarning:
#
# ...

# %%
from scipy import stats
customers_fix = pd.DataFrame()
customers_fix["Recency"] = stats.boxcox(customers['Recency'])[0]
customers_fix["Frequency"] = stats.boxcox(customers['Frequency'])[0]
customers_fix["MonetaryValue"] = stats.boxcox(customers['MonetaryValue'])[0]

customers_fix.tail()
# Out:
#          Recency  Frequency  MonetaryValue
# 3893   17.582793   3.847542       3.847542
# 3894    2.391512   2.654617       2.654617
# 3895   31.211451   0.802660       0.802660
# 3896    3.054496   5.191431       5.191431
# 3897  107.383666   2.988455       2.988455

# %%
# Import library
from sklearn.preprocessing import StandardScaler
# Initialize the Object
scaler = StandardScaler()
# Fit and Transform The Data
scaler.fit(customers_fix)
customers_normalized = scaler.transform(customers_fix)
# Assert that it has mean 0 and variance 1
print(customers_normalized.mean(axis = 0).round(2)) # [0. -0. 0.]
print(customers_normalized.std(axis = 0).round(2)) # [1. 1. 1.]
# Out:
# [-0. -0. -0.]
# [1. 1. 1.]

# %%
from sklearn.cluster import KMeans
sse = {}
for k in range(1, 11):
  kmeans = KMeans(n_clusters=k, random_state=42)
  kmeans.fit(customers_normalized)
  sse[k] = kmeans.inertia_ # SSE to closest cluster centroid
  plt.title('The Elbow Method')
plt.xlabel('k')
plt.ylabel('SSE')
sns.pointplot(x=list(sse.keys()), y=list(sse.values()))
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
model = KMeans(n_clusters=4, random_state=42)
model.fit(customers_normalized)
model.labels_.shape
customers["Cluster"] = model.labels_
customers.groupby('Cluster').agg({
    'Recency':'mean',
    'Frequency':'mean',
    }).round(2)
f, ax = plt.subplots(figsize=(25, 5))
ax = sns.countplot(x="Cluster", data=customers)
customers.groupby(['Cluster']).count()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#          Recency  Frequency  MonetaryValue
# Cluster
# 0           1214       1214           1214
# 1            958        958            958
# 2            798        798            798
# 3            928        928            928

# %%
customers["Cluster"] = model.labels_
customers.groupby('Cluster').agg({
    'Recency':'mean',
    'Frequency':'mean',
    'MonetaryValue' : 'mean'}).round(2)
# Out:
#          Recency  Frequency  MonetaryValue
# Cluster
# 0         526.65       8.94           8.94
# 1         376.17      17.07          17.07
# 2         382.11       3.62           3.62
# 3         119.14       9.35           9.35

# %%
# Create the dataframe
df_normalized = pd.DataFrame(customers_normalized, columns=[
    'Recency', 'Frequency', 'MonetaryValue'])
df_normalized['ID'] = customers.index
df_normalized['Cluster'] = model.labels_
# Melt The Data
df_nor_melt1 = pd.melt(df_normalized.reset_index(),
                      id_vars=['ID', 'Cluster'],
                      value_vars=['Recency','Frequency', 'MonetaryValue'],
                      var_name='Attribute',value_name='Value')
df_nor_melt1.head()
# Out:
#      ID  Cluster Attribute     Value
# 0  1000        1   Recency -0.590161
# 1  1001        1   Recency  0.016001
# 2  1002        3   Recency -1.111143
# 3  1003        0   Recency  1.347784
# 4  1004        1   Recency  0.673230

# %%
plt.figure(figsize=(14,7))
# Group variable using "hue" that will produce lines with different colors
sns.lineplot(x="Recency" , y="MonetaryValue", color = 'blue', data=df_normalized)

sns.lineplot(x="Recency" , y="Frequency", color = 'g', data=df_normalized)

plt.show()
